# %% [markdown]
# ## Run this only on the PYCARET Env :

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from pycaret import * 
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 200)

# %%
df = pd.read_csv("C:\\Users\\Raj_jhumpa\\Downloads\\My Projects\\Machine Learning\\Datasets\\creditcard.csv")
df.head()
df.shape
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# ## 2.0 Basic EDA :
#
# * **Checking if the data is balanced or imbalaced.**

# %%
(df['Class'].value_counts(normalize = True)*100)
# Out:
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64

# %% [markdown]
# * **The data set is imbalanced.**

# %% [markdown]
# ## 2.0 Model Building with Pycaret :

# %%
from pycaret.classification import *
clf = setup(data = df, target = 'Class')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_74c6e03a_f776_11ea_808b_7c8ae1393903" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74c6e03a_f776_11ea_808b_7c8ae1393903level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_74c6e03a_f776_11ea_808b_7c8ae1393903row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_74c6e03a_f776_11ea_808b_7c8ae1393903row0_col1" class="data row0 col1" >5768</td>
#             </tr>
#             <tr>
#                         <th id="T_74c6e03a_f776_11ea_808b_7c8ae1393903level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_74c6e03a_f776_11ea_808b_7c8ae1393903row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_aacc793c_f77e_11ea_969b_7c8ae1393903 th {
#           text-align: left;
#     }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col0 {
#             text-align:  left;
#         }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_aacc793c_f77e_11ea_969b_7c8ae1393903row0_col7 {
# ...

# %% [markdown]
# * **Since this is an imbalanced dataset,we mainly look at F1 score and Kappa Score.**
#
# * **Thus the top 2 alogrithms are Catboots and XGboost.**
# * **We will go for XGboost for model creation.**
#
# * **https://pycaret.org/create-model/**

# %%
xg_boost = create_model('xgboost')
# Out:
# <style  type="text/css" >
#     #T_cccff410_f789_11ea_a60b_7c8ae1393903row10_col0 {
#             background:  yellow;
#         }    #T_cccff410_f789_11ea_a60b_7c8ae1393903row10_col1 {
#             background:  yellow;
#         }    #T_cccff410_f789_11ea_a60b_7c8ae1393903row10_col2 {
#             background:  yellow;
#         }    #T_cccff410_f789_11ea_a60b_7c8ae1393903row10_col3 {
#             background:  yellow;
#         }    #T_cccff410_f789_11ea_a60b_7c8ae1393903row10_col4 {
#             background:  yellow;
#         }    #T_cccff410_f789_11ea_a60b_7c8ae1393903row10_col5 {
#             background:  yellow;
#         }    #T_cccff410_f789_11ea_a60b_7c8ae1393903row10_col6 {
#             background:  yellow;
# ...

# %%
# Checking trained model parameters 

xg_boost
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#               objective='binary:logistic', random_state=5768, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=0)

# %%
# Hyper Parameter Tuning : 

tuned_xg_boost = tune_model(xg_boost)
# Out:
# <style  type="text/css" >
#     #T_51456ed0_f78c_11ea_b3f9_7c8ae1393903row10_col0 {
#             background:  yellow;
#         }    #T_51456ed0_f78c_11ea_b3f9_7c8ae1393903row10_col1 {
#             background:  yellow;
#         }    #T_51456ed0_f78c_11ea_b3f9_7c8ae1393903row10_col2 {
#             background:  yellow;
#         }    #T_51456ed0_f78c_11ea_b3f9_7c8ae1393903row10_col3 {
#             background:  yellow;
#         }    #T_51456ed0_f78c_11ea_b3f9_7c8ae1393903row10_col4 {
#             background:  yellow;
#         }    #T_51456ed0_f78c_11ea_b3f9_7c8ae1393903row10_col5 {
#             background:  yellow;
#         }    #T_51456ed0_f78c_11ea_b3f9_7c8ae1393903row10_col6 {
#             background:  yellow;
# ...

# %%
tuned_xg_boost
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.51, max_delta_step=0, max_depth=70,
#               min_child_weight=3, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=-1, num_parallel_tree=1,
#               objective='binary:logistic', random_state=5768, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.9,
#               tree_method='exact', validate_parameters=1, verbosity=0)
